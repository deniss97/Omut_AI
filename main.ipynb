# %% [markdown]
# ### Шаг 1: Подготовка данных

# %%
from datasets import load_dataset
import pandas as pd

# Загрузка и подготовка данных
dataset = load_dataset('imdb')
train_data = dataset['train']
test_data = dataset['test']

# Составьте все возможные пары (positive, negative) из train подвыборки
train_df = pd.DataFrame(train_data)
positive_comments = train_df[train_df['label'] == 1]['text'].tolist()
negative_comments = train_df[train_df['label'] == 0]['text'].tolist()
pairs = [(pos, neg) for pos in positive_comments[:200] for neg in negative_comments[:200]]

# Обрезка текстов для датасета промптов
def truncate_text(text, max_tokens=20):
    tokens = text.split()
    return ' '.join(tokens[:max_tokens])

# Создание датасета промптов из тренировочной выборки
prompts_train = [truncate_text(text, max_tokens=15) for text in train_df['text'].tolist()]
prompts_train = prompts_train[:10000]

# Создание датасета промптов из тестовой выборки
prompts_test = [truncate_text(text, max_tokens=15) for text in test_data['text']]
prompts_test = prompts_test[:100]
# Out:
# Downloading readme:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %% [markdown]
# ### Шаг 2: Реализация модели наград

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, TrainingArguments
from datasets import Dataset
from trl import RewardTrainer

# Инициализация модели и токенизатора
model_name = 'distilbert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
reward_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=1)

# Подготовка данных для модели наград
def preprocess_reward_data(pairs, tokenizer, max_length=128):
    chosen_texts = [pair[0] for pair in pairs]
    rejected_texts = [pair[1] for pair in pairs]

    chosen_encodings = tokenizer(chosen_texts, padding='max_length', truncation=True, max_length=max_length, return_tensors='pt')
    rejected_encodings = tokenizer(rejected_texts, padding='max_length', truncation=True, max_length=max_length, return_tensors='pt')

    dataset_dict = {
        'input_ids_chosen': chosen_encodings['input_ids'],
        'attention_mask_chosen': chosen_encodings['attention_mask'],
        'input_ids_rejected': rejected_encodings['input_ids'],
        'attention_mask_rejected': rejected_encodings['attention_mask']
    }

    return Dataset.from_dict(dataset_dict)

pairs_dataset = preprocess_reward_data(pairs, tokenizer)
print(pairs_dataset[:2])  # Вывод первых двух элементов для проверки

# Обучение модели наград
training_args = TrainingArguments(
    output_dir='./results',
    per_device_train_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',
    save_total_limit=1,
    fp16=True
)

trainer = RewardTrainer(
    model=reward_model,
    tokenizer=tokenizer,
    train_dataset=pairs_dataset,
    args=training_args
)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 from transformers import AutoModelForSequenceClassification, AutoTokenizer, TrainingArguments
#       2 from datasets import Dataset
# ----> 3 from trl import RewardTrainer
#       5 # Инициализация модели и токенизатора
#       6 model_name = 'distilbert-base-cased'
#
# ModuleNotFoundError: No module named 'trl'

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, TrainingArguments
# Сохраняем обученную reward model
# reward_model.save_pretrained("trained_reward_model")
# tokenizer.save_pretrained("trained_reward_model")

# Загружаем reward model
reward_model = AutoModelForSequenceClassification.from_pretrained("trained_reward_model", num_labels=1)

# from transformers import DistilBertTokenizer, DistilBertModel
# tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-cased')
# reward_model = DistilBertModel.from_pretrained("distilbert-base-cased")

# %% [markdown]
# ### Шаг 3: Имплементация метода WARP

# %%
import torch
from tqdm import tqdm
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AdamW, AutoTokenizer, AutoModelForCausalLM
from collections import defaultdict
import os
from adabelief_pytorch import AdaBelief
import math
import numpy as np

# Параметры WARP
I = 2
M = 2
T = 100
mu = 0.01
eta = 0.3
batch_size = 128
lambda_ = 0.5
beta = 0.1 

# Инициализация модели GPT-2
tokenizer = AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
model = GPT2LMHeadModel.from_pretrained("lvwerra/gpt2-imdb")

# Pad token
tokenizer.pad_token = tokenizer.eos_token

# Функция генерации завершений предложений
def generate_completion(model, tokenizer, prompt, max_new_tokens=50):
    inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True)
    outputs = model.generate(inputs['input_ids'], max_new_tokens=max_new_tokens, num_return_sequences=1, attention_mask=inputs['attention_mask'], pad_token_id=tokenizer.eos_token_id, temperature=0.9)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Функция для валидирования входных данных и замены OOV токенов
def validate_and_replace_oov(input_ids, vocab_size, pad_token_id):
    if torch.any(input_ids >= vocab_size):
        print(f"Found OOV token before replacement: {input_ids}")
        input_ids = torch.where(input_ids >= vocab_size, torch.full_like(input_ids, pad_token_id), input_ids)
    if torch.any(input_ids >= vocab_size):
        print(f"Error: Still OOV tokens present after replacement: {input_ids}")
    return input_ids

# Функция для подготовки входных данных и проверки того, что они в диапазоне валидных токенов
def preprocess_inputs(prompt, completion, tokenizer, vocab_size, pad_token_id):
    reward_input = tokenizer(prompt + completion, return_tensors='pt', padding=True, truncation=True)
    reward_input_ids = reward_input['input_ids']
    
    # Валидирование и замена OOV токенов
    reward_input_ids = validate_and_replace_oov(reward_input_ids, vocab_size, pad_token_id)
    
    # Проверка на то, что входные данные входят в диапазон валидных токенов
    if torch.any(reward_input_ids >= tokenizer.vocab_size):
        raise ValueError(f"final check Failed Removing OOV tokens: {reward_input_ids}")
    
    return reward_input['input_ids'], reward_input['attention_mask']

# Функции по поиску повторяющихся токенов
def find_repeated_ngrams(tokens, n):
    ngram_counts = defaultdict(int)
    repeated_ngrams = set()

    for i in range(len(tokens) - n + 1):
        ngram = tuple(tokens[i:i + n])
        ngram_counts[ngram] += 1
        if ngram_counts[ngram] > 1:
            repeated_ngrams.add(ngram)

    return repeated_ngrams

def clean_repetitive_tokens(text, max_repeats=2, ngram_min=2, ngram_max=5):
    tokens = text.split()
    
    # 1: Limit n-gram repetitions
    for n in range(ngram_min, ngram_max + 1):
        repeated_ngrams = find_repeated_ngrams(tokens, n)
        for ngram in repeated_ngrams:
            count = 0
            new_tokens = []
            i = 0
            while i < len(tokens):
                current_ngram = tuple(tokens[i:i + n])
                if current_ngram == ngram:
                    count += 1
                    if count <= max_repeats:
                        new_tokens.extend(current_ngram)
                    # Skip the repeated ngram
                    i += n
                else:
                    new_tokens.append(tokens[i])
                    i += 1
            tokens = new_tokens

    # 2: Limit single token repetitions
    clean_tokens = []
    prev_token = ''
    repeat_count = 0

    for token in tokens:
        if token == prev_token:
            repeat_count += 1
        else:
            repeat_count = 0

        if repeat_count < max_repeats:
            clean_tokens.append(token)
        prev_token = token

    return ' '.join(clean_tokens)

# SLERP interpolation
# def slerp(theta_init, thetas, lam):
#     theta_slerp = {}
#     for name in theta_init:
#         # Подсчёт deltas
#         deltas = [theta[name] - theta_init[name] for theta in thetas]

#         # Подсчёт omega
#         norm_delta1 = torch.norm(deltas[0])
#         norm_delta2 = torch.norm(deltas[1])
#         cos_omega = (deltas[0] * deltas[1]).sum() / (norm_delta1 * norm_delta2)  # Элементное умножение и сумма всех элементов
#         omega = torch.acos(cos_omega).item()

#         # Подсчёт SLERP interpolation
#         sin_omega = math.sin(omega)
#         theta_slerp[name] = theta_init[name] + (
#             (math.sin((1 - lam) * omega) / sin_omega) * deltas[0] +
#             (math.sin(lam * omega) / sin_omega) * deltas[1]
#         )
    
#     return theta_slerp

def slerp(val, low, high):
    omega = np.arccos(np.clip(np.dot(low / np.linalg.norm(low), high / np.linalg.norm(high)), -1.0, 1.0))
    so = np.sin(omega)
    if so == 0:
        return (1.0 - val) * low + val * high  # Fallback for very small angles
    return (np.sin((1.0 - val) * omega) / so) * low + (np.sin(val * omega) / so) * high

def slerp_tensors(val, low, high):
    assert low.shape == high.shape, "Input tensors must have the same shape for slerp"
    low_np, high_np = low.cpu().numpy(), high.cpu().numpy()
    result_np = np.zeros_like(low_np, dtype=low_np.dtype)
    if len(low_np.shape) == 1:
        result_np = slerp(val, low_np, high_np)
    else:
        for i in range(low_np.shape[0]):
            result_np[i] = slerp(val, low_np[i], high_np[i])
    result_tensor = torch.from_numpy(result_np).to(low.device)
    return result_tensor

def weighted_average(weights_list, weight_decay):
    """
    Выполняет взвешенное среднее по экземплярам состояний моделей.
    """
    avg_state_dict = weights_list[0].copy()
    for key in avg_state_dict.keys():
        avg_state_dict[key] = torch.stack([weights[key] for weights in weights_list], dim=0).mean(dim=0)
    return {key: weight_decay * avg_state_dict[key] + (1 - weight_decay) * torch.stack([weights[key] for weights in weights_list], dim=0).mean(dim=0) for key in avg_state_dict.keys()}

# Обучение WARP
def wrap(model, reward_model, tokenizer, prompts_train, I, M, T, beta, mu, eta, batch_size):
    theta_init = model.state_dict()
    for i in range(I):
        theta_m_list = []
        for m in range(M):
            model.load_state_dict(theta_init)
            ema_state_dict = {k: v.clone() for k, v in theta_init.items()}
            
            optimizer = AdaBelief(model.parameters(), lr=1e-6, print_change_log = False)
            
            for t in tqdm(range(T), desc=f"Iteration {i+1}, Run {m+1}"):
                batch_prompts = np.random.choice(prompts_train, batch_size, replace=False)
                
                # Генерация продолжений
                completions = [generate_completion(model, tokenizer, prompt) for prompt in batch_prompts]
                
                # Подсчёт наград
                rewards = []
                for prompt, completion in zip(batch_prompts, completions):
                    try:
                        completion = clean_repetitive_tokens(completion)
                        reward_input_ids, attention_mask = preprocess_inputs(prompt, completion, tokenizer, tokenizer.vocab_size, tokenizer.pad_token_id)
                        # print("0")
                        reward_output = reward_model(reward_input_ids, attention_mask=attention_mask)
                        # print("123")
                        if isinstance(reward_output, dict):
                            reward = reward_output['logits'][0].item()
                        else:
                            reward = reward_output.logits[0].item()

                        # print("456")
                        with torch.no_grad():
                            model_outputs = model(reward_input_ids, attention_mask=attention_mask).logits
                            ema_model_outputs = model(reward_input_ids, attention_mask=attention_mask).logits
                            kl_div = torch.nn.functional.kl_div(
                                torch.log_softmax(model_outputs, dim=-1),
                                torch.softmax(ema_model_outputs, dim=-1),
                                reduction='batchmean'
                            )
                        rewards.append(reward - beta * kl_div.item())
                        # print("789")
                    except Exception as e:
                        # print(f"Error during reward computation: {e}")
                        continue
                        
                # Обновление параметров модели
                if rewards:
                    rewards_tensor = torch.tensor(rewards, dtype=torch.float32, requires_grad=True)
                    loss = -torch.mean(rewards_tensor)

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    
                    # Обновление EMA weights
                    with torch.no_grad():
                        state_dict = model.state_dict()
                        for name, param in state_dict.items():
                            ema_state_dict[name].data.copy_((1 - mu) * ema_state_dict[name].data + mu * param)
            
            theta_m = model.state_dict()
            theta_m_list.append(theta_m)

        # SLERP Weight Interpolation
        theta_slerp_i = theta_m_list[0].copy()
        for param_name in theta_slerp_i:
            for j in range(1, len(theta_m_list)):
                theta_slerp_i[param_name] = slerp_tensors(1 / (j + 1), theta_slerp_i[param_name], theta_m_list[j][param_name])

        # LITI Interpolation with initial weights
        for name in theta_init:
            theta_init[name] = (1 - eta) * theta_init[name] + eta * theta_slerp_i[name]
    
    # Сохранение Pareto front weights
    pareto_front = []
    for eta in range(0, 5):
        eta_val = eta / 4.0
        model_weights = {name: (1 - eta_val) * theta_init[name] + eta_val * theta_slerp_i[name] for name in theta_init}
        pareto_front.append(model_weights)
        
    save_dir = "./pareto_models"
    os.makedirs(save_dir, exist_ok=True)
    for i, model_weights in enumerate(pareto_front):
        model_path = os.path.join(save_dir, f"model_weights_{i}.pth")
        torch.save(model_weights, model_path)
        print(f"Saved model: {model_path}")
    
    return pareto_front

# Вывод модели для тестирования
pareto_front = wrap(model, reward_model, tokenizer, prompts_train, I, M, T, beta, mu, eta, batch_size)
# Out:
# Weight decoupling enabled in AdaBelief
# Rectification enabled in AdaBelief
# Iteration 1, Run 1:   0%|          | 0/100 [00:00<?, ?it/s]/opt/conda/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Iteration 1, Run 1: 100%|██████████| 100/100 [3:06:01<00:00, 111.62s/it]
# Weight decoupling enabled in AdaBelief
# Rectification enabled in AdaBelief
# Iteration 1, Run 2: 100%|██████████| 100/100 [3:05:43<00:00, 111.43s/it]
# Weight decoupling enabled in AdaBelief
# Rectification enabled in AdaBelief
# Iteration 2, Run 1: 100%|██████████| 100/100 [3:07:34<00:00, 112.54s/it]
# Weight decoupling enabled in AdaBelief
# Rectification enabled in AdaBelief
# Iteration 2, Run 2: 100%|██████████| 100/100 [3:04:49<00:00, 110.90s/it]
# Saved model: ./pareto_models/model_weights_0.pth
# Saved model: ./pareto_models/model_weights_1.pth
# Saved model: ./pareto_models/model_weights_2.pth
# Saved model: ./pareto_models/model_weights_3.pth
# Saved model: ./pareto_models/model_weights_4.pth

# %% [markdown]
# ### Шаг 4: Оценка модели

# %%
from collections import defaultdict
import torch.nn.functional as F

# Функция генерации завершений предложений
def generate_completion(model, tokenizer, prompt, max_length=50):
    inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
    outputs = model.generate(inputs['input_ids'], max_length=max_length, num_return_sequences=1, attention_mask=inputs['attention_mask'], pad_token_id=tokenizer.eos_token_id)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Функция для валидирования входных данных и замены OOV токенов
def validate_and_replace_oov(input_ids, vocab_size, pad_token_id):
    if torch.any(input_ids >= vocab_size):
        print(f"Found OOV token before replacement: {input_ids}")
        input_ids = torch.where(input_ids >= vocab_size, torch.full_like(input_ids, pad_token_id), input_ids)
    if torch.any(input_ids >= vocab_size):
        print(f"Error: Still OOV tokens present after replacement: {input_ids}")
    return input_ids

# Функция для подготовки входных данных и проверки того, что они в диапазоне валидных токенов
def preprocess_inputs(prompt, completion, tokenizer, vocab_size, pad_token_id):
    reward_input = tokenizer(prompt + completion, return_tensors='pt', padding=True, truncation=True)
    reward_input_ids = reward_input['input_ids']
    
    # Валидирование и замена OOV токенов
    reward_input_ids = validate_and_replace_oov(reward_input_ids, vocab_size, pad_token_id)
    
    # Проверка на то, что входные данные входят в диапазон валидных токенов
    if torch.any(reward_input_ids >= tokenizer.vocab_size):
        raise ValueError(f"final check Failed Removing OOV tokens: {reward_input_ids}")
    
    return reward_input['input_ids'], reward_input['attention_mask']

# Функции по поиску повторяющихся токенов
def find_repeated_ngrams(tokens, n):
    ngram_counts = defaultdict(int)
    repeated_ngrams = set()

    for i in range(len(tokens) - n + 1):
        ngram = tuple(tokens[i:i + n])
        ngram_counts[ngram] += 1
        if ngram_counts[ngram] > 1:
            repeated_ngrams.add(ngram)

    return repeated_ngrams

def clean_repetitive_tokens(text, max_repeats=2, ngram_min=2, ngram_max=5):
    tokens = text.split()
    
    # 1: Limit n-gram repetitions
    for n in range(ngram_min, ngram_max + 1):
        repeated_ngrams = find_repeated_ngrams(tokens, n)
        for ngram in repeated_ngrams:
            count = 0
            new_tokens = []
            i = 0
            while i < len(tokens):
                current_ngram = tuple(tokens[i:i + n])
                if current_ngram == ngram:
                    count += 1
                    if count <= max_repeats:
                        new_tokens.extend(current_ngram)
                    # Skip the repeated ngram
                    i += n
                else:
                    new_tokens.append(tokens[i])
                    i += 1
            tokens = new_tokens

    # 2: Limit single token repetitions
    clean_tokens = []
    prev_token = ''
    repeat_count = 0

    for token in tokens:
        if token == prev_token:
            repeat_count += 1
        else:
            repeat_count = 0

        if repeat_count < max_repeats:
            clean_tokens.append(token)
        prev_token = token

    return ' '.join(clean_tokens)

# def generate_completion(model, tokenizer, prompt, pad_token_id=50256, max_length=50):
#     inputs = tokenizer(prompt, return_tensors="pt")
#     outputs = model.generate(
#         **inputs,
#         pad_token_id=pad_token_id,
#         max_length=max_length,
#         num_return_sequences=1,
#         no_repeat_ngram_size=3,  # Предотвращение повторений
#         repetition_penalty=2.5,  # Штраф за повторение
#         eos_token_id=pad_token_id,
#         temperature=0.7,         # Пониженная температура
#         top_k=50,                # Обрезка по top_k
#         top_p=0.95               # Метод nucleus sampling
#     )
#     return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Средняя награда и KL дивергенция для обученной модели
def evaluate_model(model, prompts_test, reward_model, tokenizer):
    rewards = []
    kl_divs = []
    
    for index, prompt in enumerate(prompts_test):
        print(f"Processing prompt {index + 1}/{len(prompts_test)}")
        try:
            completion = generate_completion(model, tokenizer, prompt)
            # completion = clean_repetitive_tokens(completion)
            print(f"Prompt: {prompt}")
            print(f"Completion: {completion}")

            reward_input_ids, attention_mask = preprocess_inputs(prompt, completion, tokenizer, tokenizer.vocab_size, tokenizer.pad_token_id)
            reward = reward_model(reward_input_ids, attention_mask=attention_mask).logits[0].item()
            kl_div = F.kl_div(
                F.log_softmax(model(reward_input_ids, attention_mask=attention_mask).logits, dim=-1),
                F.softmax(sft_model(reward_input_ids, attention_mask=attention_mask).logits, dim=-1), reduction='batchmean'
            )
            rewards.append(reward)
            kl_divs.append(kl_div.item())
        except IndexError as e:
            continue
            print(f"IndexError encountered for prompt {index + 1}: {e}")
    
    if len(rewards) > 0:
        avg_reward = sum(rewards) / len(rewards)
    else:
        avg_reward = 0.0  # или любое другое значение по умолчанию, которое имеет смысл в вашем контексте

    if len(kl_divs) > 0:
        avg_kl_div = sum(kl_divs) / len(kl_divs)
    else:
        avg_kl_div = 0.0
    print(f'Average Reward: {avg_reward}, Average KL Divergence: {avg_kl_div}')
    return avg_reward, avg_kl_div


# Средняя награда и KL дивергенция для обученной модели
model_name = "lvwerra/gpt2-imdb"
sft_model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
tokenizer.pad_token = tokenizer.eos_token

# Оценка средних наград и KL дивергенции для нескольких моделей из Pareto фронта
model_paths = ['./pareto_models/model_weights_0.pth', 
               './pareto_models/model_weights_1.pth', 
               './pareto_models/model_weights_2.pth', 
               './pareto_models/model_weights_3.pth', 
               './pareto_models/model_weights_4.pth']
results = []

for model_path in model_paths:
    pareto_model = GPT2LMHeadModel.from_pretrained(model_name)
    state_dict = torch.load(model_path)
    pareto_model.load_state_dict(state_dict)
    avg_reward, avg_kl_div = evaluate_model(pareto_model, prompts_test, reward_model, tokenizer)
    results.append((model_path, avg_reward, avg_kl_div))

# Оценка модели SFT
avg_reward_sft, avg_kl_div_sft = evaluate_model(sft_model, prompts_test, reward_model, tokenizer)
results.append(("SFT Model", avg_reward_sft, avg_kl_div_sft))

# Оценка модели
avg_reward_model, avg_kl_div_model = evaluate_model(model, prompts_test, reward_model, tokenizer)
results.append(("Model", avg_reward_model, avg_kl_div_model))

for result in results:
    print(f"Model: {result[0]}, Avg Reward: {result[1]}, Avg KL Divergence: {result[2]}")
# Out:
# /tmp/ipykernel_169/979561626.py:156: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# Processing prompt 1/100
# Prompt: I love sci-fi and am willing to put up with a lot. Sci-fi movies/TV are
# Completion: I love sci-fi and am willing to put up with a lot. Sci-fi movies/TV are not for everyone, but I do enjoy them. I love the fact that the characters are real people, and that they are not just a
# Processing prompt 2/100
# Prompt: Worth the entertainment value of a rental, especially if you like action movies. This one
# Completion: Worth the entertainment value of a rental, especially if you like action movies. This one is a must see.
# Processing prompt 3/100
# Prompt: its a totally average film with a few semi-alright action sequences that make the plot
# Completion: its a totally average film with a few semi-alright action sequences that make the plot seem like it's going nowhere. The acting is average, the script is bad, and the acting is bad. The only thing that makes this film worth watching
# Processing prompt 4/100
# Prompt: STAR RATING: ***** Saturday Night **** Friday Night *** Friday Morning ** Sunday Night *
# Completion: STAR RATING: ***** Saturday Night **** Friday Night *** Friday Morning ** Sunday Night * Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning
# Processing prompt 5/100
# Prompt: First off let me say, If you haven't enjoyed a Van Damme movie since bloodsport,
# Completion: First off let me say, If you haven't enjoyed a Van Damme movie since bloodsport, then you'll love this one. It's a great movie, and I'm sure you'll enjoy it too.
# Processing prompt 6/100
# Prompt: I had high hopes for this one until they changed the name to 'The Shepherd
# Completion: I had high hopes for this one until they changed the name to 'The Shepherd'. I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good
# Processing prompt 7/100
# Prompt: Isaac Florentine has made some of the best western Martial Arts action movies ever produced.
# Completion: Isaac Florentine has made some of the best western Martial Arts action movies ever produced. He is a master of the martial arts and has made some of the best western action movies ever made. He is a master of the martial arts and has
# Processing prompt 8/100
# Prompt: It actually pains me to say it, but this movie was horrible on every level.
# Completion: It actually pains me to say it, but this movie was horrible on every level. The acting was terrible, the plot was terrible, the acting was terrible, the plot was terrible, the acting was terrible, the acting was terrible, the acting was
# Processing prompt 9/100
# Prompt: Technically I'am a Van Damme Fan, or I was. this movie is so bad that
# Completion: Technically I'am a Van Damme Fan, or I was. this movie is so bad that I'm going to give it a 10.
# Processing prompt 10/100
# Prompt: Honestly awful film, bad editing, awful lighting, dire dialog and scrappy screenplay.<br /><br />The lighting
# Completion: Honestly awful film, bad editing, awful lighting, dire dialog and scrappy screenplay.<br /><br />The lighting is terrible, the acting is terrible, the script is bad, the acting is bad, the script is bad, the script is
# Processing prompt 11/100
# Prompt: This flick is a waste of time.I expect from an action movie to have more
# Completion: This flick is a waste of time.I expect from an action movie to have more than one action scene.The acting is terrible.The plot is so bad that it's hard to believe that it was made in the first place.The acting is
# Processing prompt 12/100
# Prompt: Blind Date (Columbia Pictures, 1934), was a decent film, but I have a few issues
# Completion: Blind Date (Columbia Pictures, 1934), was a decent film, but I have a few issues with it. First, the story is very predictable. The characters are all very predictable. The plot is very predictable. The acting is very predictable
# Processing prompt 13/100
# Prompt: I first watched this movie back in the mid/late 80's, when I was a kid.
# Completion: I first watched this movie back in the mid/late 80's, when I was a kid. I remember it as a very funny movie, and I still remember it as a very funny movie. I think it's a very good movie, and
# Processing prompt 14/100
# Prompt: I saw the Mogul Video VHS of this. That's another one of those old 1980s
# Completion: I saw the Mogul Video VHS of this. That's another one of those old 1980s horror movies that you can't get ahold of. I'm not sure if it was the original or the remake, but I think it was a
# Processing prompt 15/100
# Prompt: A group of heirs to a mysterious old mansion find out that they have to
# Completion: A group of heirs to a mysterious old mansion find out that they have to find out who the real owner of the mansion is. The film is a bit slow, but it's a good film.
# Processing prompt 16/100
# Prompt: Now, I LOVE Italian horror films. The cheesier they are, the better. However, this is
# Completion: Now, I LOVE Italian horror films. The cheesier they are, the better. However, this is a film that I would recommend to anyone who likes Italian horror films.
# Processing prompt 17/100
# Prompt: This cheap, grainy-filmed Italian flick is about a couple of inheritors of a manor in
# Completion: This cheap, grainy-filmed Italian flick is about a couple of inheritors of a manor in the Italian countryside. The film is about a couple of people who are trying to get their inheritance back. The film is about a couple of
# Processing prompt 18/100
# Prompt: I just finished watching this movie and am disappointed to say that I didn't enjoy
# Completion: I just finished watching this movie and am disappointed to say that I didn't enjoy it. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but
# Processing prompt 19/100
# Prompt: Ben, (Rupert Grint), is a deeply unhappy adolescent, the son of his unhappily married parents.
# Completion: Ben, (Rupert Grint), is a deeply unhappy adolescent, the son of his unhappily married parents. He is a very good actor, but he is not a good actor. He is a very good actor, but he is not
# Processing prompt 20/100
# Prompt: Every movie I have PPV'd because Leonard Maltin praised it to the skies has blown
# Completion: Every movie I have PPV'd because Leonard Maltin praised it to the skies has blown me away. I have seen it twice and I have seen it twice more. I have seen it twice and I have seen it twice more. I have seen
# Processing prompt 21/100
# Prompt: Low budget horror movie. If you don't raise your expectations too high, you'll probably enjoy
# Completion: Low budget horror movie. If you don't raise your expectations too high, you'll probably enjoy this one.
# Processing prompt 22/100
# Prompt: Dr Stephens (Micheal Harvey) runs a mental asylum. He has a different approach to the
# Completion: Dr Stephens (Micheal Harvey) runs a mental asylum. He has a different approach to the asylum, and he is a bit of a jerk. He is a bit of a jerk, but he is a jerk nonetheless. He is a jerk
# Processing prompt 23/100
# Prompt: The Forgotten (AKA: Don't Look In The Basement) is a very cheaply made and very
# Completion: The Forgotten (AKA: Don't Look In The Basement) is a very cheaply made and very poorly acted film. The acting is poor and the script is very poor. The only reason I gave it a 7 is because of the fact that
# Processing prompt 24/100
# Prompt: This movie had a very unique effect on me: it stalled my realization that this
# Completion: This movie had a very unique effect on me: it stalled my realization that this was a movie that I was going to watch for the rest of my life. I was so excited to see this movie, I was so excited to see the movie that
# Processing prompt 25/100
# Prompt: too bad this movie isn't. While "Nemesis Game" is mildly entertaining, I found it hard
# Completion: too bad this movie isn't. While "Nemesis Game" is mildly entertaining, I found it hard to believe that it would be so bad. The acting is terrible, the plot is so bad, and the acting is so bad that it
# Processing prompt 26/100
# Prompt: I of course saw the previews for this at the beginning of some other Lion's
# Completion: I of course saw the previews for this at the beginning of some other Lion's Gate movies, and I was very impressed. I was also very impressed with the way the movie was shot. The camera work was very good, and the acting was very
# Processing prompt 27/100
# Prompt: I gave this a 3 out of a possible 10 stars.<br /><br />Unless you like
# Completion: I gave this a 3 out of a possible 10 stars.<br /><br />Unless you like to see a good movie with a good story, this is a must see.
# Processing prompt 28/100
# Prompt: I was looking forward to this movie. Trustworthy actors, interesting plot. Great atmosphere then ?????
# Completion: I was looking forward to this movie. Trustworthy actors, interesting plot. Great atmosphere then?????
# Processing prompt 29/100
# Prompt: Four things intrigued me as to this film - firstly, it stars Carly Pope (of
# Completion: Four things intrigued me as to this film - firstly, it stars Carly Pope (of the TV series 'The Simpsons') as the main character, and secondly, it is a very funny film. The humour is very good, and the characters are
# Processing prompt 30/100
# Prompt: <br /><br />Never ever take a film just for its good looking title.<br /><br />Although
# Completion: <br /><br />Never ever take a film just for its good looking title.<br /><br />Although the film is a bit slow, it is still a good film. The acting is good, the story is good, and the
# Processing prompt 31/100
# Prompt: Lowe returns to the nest after, yet another, failed relationship, to find he's been assigned
# Completion: Lowe returns to the nest after, yet another, failed relationship, to find he's been assigned to a different job. He's a man who's been in a relationship for a long time, and he's not happy with the way things are
# Processing prompt 32/100
# Prompt: Seriously, I can't imagine how anyone could find a single flattering thing to say about
# Completion: Seriously, I can't imagine how anyone could find a single flattering thing to say about this movie. I'm not even going to go into the plot, but I'll just say that it's a very bad movie. I'm not even going to
# Processing prompt 33/100
# Prompt: I'm the type of guy who loves hood movies from New Jack City to Baby
# Completion: I'm the type of guy who loves hood movies from New Jack City to Baby Driver. I'm also a big fan of the "The Big Chill" series, which I've seen a lot. I'm also a big fan of the "The
# Processing prompt 34/100
# Prompt: The most positive points in this film were the credits (text style) and some moments
# Completion: The most positive points in this film were the credits (text style) and some moments of humor. The film was a bit slow, but it was a good film.
# Processing prompt 35/100
# Prompt: I quite enjoyed The Wrecking Crew (1999), which was the last of the three films
# Completion: I quite enjoyed The Wrecking Crew (1999), which was the last of the three films I saw. I was very impressed with the direction and the acting. The film was very well done and the story was very well told. The acting was
# Processing prompt 36/100
# Prompt: this film has no plot, no good acting, to be honest it has nothing, the
# Completion: this film has no plot, no good acting, to be honest it has nothing, the only thing that makes it worth watching is the music. I think it's a shame that the director didn't make a sequel to this one.
# Processing prompt 37/100
# Prompt: Beware, My Lovely (1952) Dir: Harry Horner <br /><br />Production: The Filmmakers/RKO Radio Pictures<br /><br
# Completion: Beware, My Lovely (1952) Dir: Harry Horner <br /><br />Production: The Filmmakers/RKO Radio Pictures<br /><br />Director: Harry Horner <br /><br />Director:
# Processing prompt 38/100
# Prompt: The only reason this movie is not given a 1 (awful) vote is that the
# Completion: The only reason this movie is not given a 1 (awful) vote is that the movie is so bad it's hard to believe it was made in the first place. The acting is terrible, the plot is so bad it's hard to believe
# Processing prompt 39/100
# Prompt: Artificial melodrama with a screenplay adapted by Mel Dinelli from his play "The Man" concerns
# Completion: Artificial melodrama with a screenplay adapted by Mel Dinelli from his play "The Man" concerns a young man who is sent to a boarding school for his studies. He is sent to a boarding school for his studies, but he is not
# Processing prompt 40/100
# Prompt: Wow, what an overrated movie this turned out to be! It was supposed to be
# Completion: Wow, what an overrated movie this turned out to be! It was supposed to be a comedy, but it was just a bunch of people laughing at each other. I mean, it was supposed to be a comedy, but it was just a
# Processing prompt 41/100
# Prompt: I can't believe the high marks people have given this film on this site. The
# Completion: I can't believe the high marks people have given this film on this site. The acting is terrible, the script is terrible, the direction is terrible, the direction is terrible, the direction is terrible, the direction is terrible, the direction is terrible
# Processing prompt 42/100
# Prompt: Widow hires a psychopath as a handyman. Sloppy film noir thriller which doesn't make much
# Completion: Widow hires a psychopath as a handyman. Sloppy film noir thriller which doesn't make much sense. The plot is a bit predictable, but the acting is good. The story is a bit predictable, but the acting is good.
# Processing prompt 43/100
# Prompt: I have no idea how anyone can give this movie high marks. I didn't rent
# Completion: I have no idea how anyone can give this movie high marks. I didn't rent it because I was bored and I didn't want to waste my time. I rented it because I was bored and I didn't want to waste my time.
# Processing prompt 44/100
# Prompt: Seeing the title of this movie "Stupid Teenagers Must Die" made me believe this was
# Completion: Seeing the title of this movie "Stupid Teenagers Must Die" made me believe this was a movie that would be a hit. I was wrong. I was wrong. I was wrong. I was wrong. I was wrong. I was wrong
# Processing prompt 45/100
# Prompt: Now I understand that this took two months to shoot. Really? I'm pretty certain my
# Completion: Now I understand that this took two months to shoot. Really? I'm pretty certain my wife and I were in the same room at the time. I'm sure it was a lot of work. I'm sure it was a lot of work.
# Processing prompt 46/100
# Prompt: STMD! is not a terrible movie, but it IS quite forgettable. The lighting is intentionally
# Completion: STMD! is not a terrible movie, but it IS quite forgettable. The lighting is intentionally bad, and the acting is terrible. The only good thing about this movie is that it is a very good movie.
# Processing prompt 47/100
# Prompt: Okay, so it was never going to change the world, and it bombed at the
# Completion: Okay, so it was never going to change the world, and it bombed at the box office. I'm not sure if it was because of the fact that it was a remake of the original, or because of the fact that it was a remake
# Processing prompt 48/100
# Prompt: A sprawling, overambitious, plotless comedy that has no dramatic center. It was probably intended to
# Completion: A sprawling, overambitious, plotless comedy that has no dramatic center. It was probably intended to be a comedy, but it's not. It's a comedy that is about a man who is a man who is a man who is a
# Processing prompt 49/100
# Prompt: No, no, no, no, no, no, NO! This is not a film, this is an
# Completion: No, no, no, no, no, no, NO! This is not a film, this is an action film. It is a film that is not a film, it is a film that is not a film. It is a film
# Processing prompt 50/100
# Prompt: I found this movie really hard to sit through, my attention kept wandering off the
# Completion: I found this movie really hard to sit through, my attention kept wandering off the screen. I was so bored that I couldn't even finish the movie. I was so bored that I couldn't even finish the movie. I was so bored that I
# Processing prompt 51/100
# Prompt: OK, so my summary line is a cheap trick. But the movie is full of
# Completion: OK, so my summary line is a cheap trick. But the movie is full of holes. The acting is terrible, the plot is stupid, and the acting is bad. The only thing that makes this movie worth watching is the acting. I'm
# Processing prompt 52/100
# Prompt: An obscure horror show filmed in the Everglades. Two couples stay overnight in a cabin
# Completion: An obscure horror show filmed in the Everglades. Two couples stay overnight in a cabin in the woods. The first couple is a woman and the second a man. The first couple is a man and the second a woman. The first couple is
# Processing prompt 53/100
# Prompt: This film is about a couple that decides to take a vacation to The Everglades
# Completion: This film is about a couple that decides to take a vacation to The Everglades. They decide to go to the Everglades to see the beautiful scenery. The film is about a couple that decides to take a vacation to The Everglades
# Processing prompt 54/100
# Prompt: Talented screenwriter Alvin Sargent sadly cannot get any engaging ideas cooking in this artificial trifle
# Completion: Talented screenwriter Alvin Sargent sadly cannot get any engaging ideas cooking in this artificial trifle. The plot is so predictable and predictable that it's hard to believe that it was written by a man who has never read a book. The only
# Processing prompt 55/100
# Prompt: An Italian/American co-production co-starring Linda Blair and David 'The Hoff' Hasselhoff: how could any fan
# Completion: An Italian/American co-production co-starring Linda Blair and David 'The Hoff' Hasselhoff: how could any fan of the genre ever get involved in this film?<br /><br />The film is a very good example
# Processing prompt 56/100
# Prompt: Oh my... bad clothing, worse synth music and the worst: David Hasselhoff. The 80's are
# Completion: Oh my... bad clothing, worse synth music and the worst: David Hasselhoff. The 80's are a time when the music was more than just a bunch of people playing a song. The 80's were a time when the music was more
# Processing prompt 57/100
# Prompt: There are many different versions of this one floating around, so make sure you can
# Completion: There are many different versions of this one floating around, so make sure you can find the one you like.
# Processing prompt 58/100
# Prompt: Witchcraft/Witchery/La Casa 4/ and whatever else you wish to call it. How about..Crud.<br /><br />A
# Completion: Witchcraft/Witchery/La Casa 4/ and whatever else you wish to call it. How about..Crud.<br /><br />A lot of people have commented on the fact that the movie is a bit too long
# Processing prompt 59/100
# Prompt: "Witchery" might just be the most incoherent and lamentably scripted horror movie of the 80's
# Completion: "Witchery" might just be the most incoherent and lamentably scripted horror movie of the 80's. The plot is so bad it's almost laughable. The acting is so bad it's almost laughable. The acting is so bad it's
# Processing prompt 60/100
# Prompt: Witchy Hildegard Knef traps a group of people in an isolated hotel and picks them
# Completion: Witchy Hildegard Knef traps a group of people in an isolated hotel and picks them up. The film is a bit slow, but it's still a good film.
# Processing prompt 61/100
# Prompt: A really very bad movie, with a very few good moments or qualities.<br /><br />It
# Completion: A really very bad movie, with a very few good moments or qualities.<br /><br />It's a shame that the movie was not released in the US.
# Processing prompt 62/100
# Prompt: This film features two of my favorite guilty pleasures. Sure, the effects are laughable, the
# Completion: This film features two of my favorite guilty pleasures. Sure, the effects are laughable, the acting is terrible, and the plot is a little too predictable. But the film is worth watching for the sheer sheer brilliance of the characters.
# Processing prompt 63/100
# Prompt: I watched this movie purely for the setting. It was filmed in an old hotel
# Completion: I watched this movie purely for the setting. It was filmed in an old hotel in the middle of nowhere, and the actors were all in their early twenties. The movie was shot in a small town in the middle of nowhere, and the actors were
# Processing prompt 64/100
# Prompt: This only gets bashed because it stars David Hasselhoff. Well, then let me bash it
# Completion: This only gets bashed because it stars David Hasselhoff. Well, then let me bash it. I'm not sure if it's because of the fact that Hasselhoff is a big fan of the show, or because he's a big
# Processing prompt 65/100
# Prompt: We brought this film as a joke for a friend, and could of been our
# Completion: We brought this film as a joke for a friend, and could of been our best friend. We were both very happy with the film, and we were both very happy with the ending. I think it was a very good film, and I think
# Processing prompt 66/100
# Prompt: Humm, an Italian movie starred by David hasselhoff and Linda Blair, I wasn´t expecting very
# Completion: Humm, an Italian movie starred by David hasselhoff and Linda Blair, I wasn´t expecting very much from this movie. The plot is very simple, the characters are very well developed and the story is very well told. The acting is
# Processing prompt 67/100
# Prompt: I and a friend rented this movie. We both found the movie soundtrack and production
# Completion: I and a friend rented this movie. We both found the movie soundtrack and production values to be very good. The acting was very good and the story was very well told. The movie was very well written and acted. The movie was very well acted
# Processing prompt 68/100
# Prompt: I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up
# Completion: I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up being boring. I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up being boring.
# Processing prompt 69/100
# Prompt: Not like I went in expecting a lot out of it, but I was at
# Completion: Not like I went in expecting a lot out of it, but I was at least expecting a good movie. I was expecting a good movie, but I was expecting a bad movie. I was expecting a bad movie, but I was expecting a good
# Processing prompt 70/100
# Prompt: That snarl...<br /><br />That scowl...<br /><br />The acts of random violence...<br /><br />The gutteral voice...<br
# Completion: That snarl...<br /><br />That scowl...<br /><br />The acts of random violence...<br /><br />The gutteral voice...<br /><br />The sound of the car...
# Processing prompt 71/100
# Prompt: generally speaking I don't make negative comments on here. But since this is a festival
# Completion: generally speaking I don't make negative comments on here. But since this is a festival, I thought it would be a good idea to give it a try. I was pleasantly surprised by the quality of the film. The acting was good, the
# Processing prompt 72/100
# Prompt: This show should be titled, "When Bad Writing Happens To Good Actors" considering most of
# Completion: This show should be titled, "When Bad Writing Happens To Good Actors" considering most of the actors are in their late 30s or early 40s. The show is a great example of how to make a good actor look good. The
# Processing prompt 73/100
# Prompt: I thought maybe... maybe this could be good. An early appearance by the Re-Animator (Jeffery
# Completion: I thought maybe... maybe this could be good. An early appearance by the Re-Animator (Jeffery) and a cameo by the "Citizen Kane" (John Cusack) was a good idea. The movie was a bit slow
# Processing prompt 74/100
# Prompt: 1983's "Frightmare" is an odd little film. The director seems to be trying to combine
# Completion: 1983's "Frightmare" is an odd little film. The director seems to be trying to combine the best of the best of the best, but it's not quite as good as the first film. The film is a bit slow, but
# Processing prompt 75/100
# Prompt: I don't get it! The teenage leads in "Horror Star" supposedly all are devoted horror
# Completion: I don't get it! The teenage leads in "Horror Star" supposedly all are devoted horror fans, but they're not. The film is a complete waste of time and money. The acting is atrocious, the direction is atrocious,
# Processing prompt 76/100
# Prompt: Conrad Radzoff(Ferdy Mayne), a hammy cult icon, dies from a heart ailment(not before disposing of
# Completion: Conrad Radzoff(Ferdy Mayne), a hammy cult icon, dies from a heart ailment(not before disposing of his body)and his wife, who is a devoted mother, is left to fend for herself. The
# Processing prompt 77/100
# Prompt: One of the last surviving horror screen greats - Conrad Radzoff - dies and has
# Completion: One of the last surviving horror screen greats - Conrad Radzoff - dies and has to be buried in a cemetery. He is buried in a cemetery, and the cemetery is haunted by a ghost. The ghost is a young woman who is a
# Processing prompt 78/100
# Prompt: My parents used to rent a lot of horror movies when I was a child.
# Completion: My parents used to rent a lot of horror movies when I was a child. I remember seeing this movie when I was a kid and I was very excited to see it. I was very excited to see it when I was a kid and I was
# Processing prompt 79/100
# Prompt: Frightmare begins with a horror movie icon killing a director and then his servant before
# Completion: Frightmare begins with a horror movie icon killing a director and then his servant before he can kill himself. The film is a bit of a mess, but it's a good one. The acting is good, the plot is good, and the
# Processing prompt 80/100
# Prompt: It's Saturday, it's raining, and I think every movie should have at least one comment...
# Completion: It's Saturday, it's raining, and I think every movie should have at least one comment...<br /><br />I'm not sure if I'm being generous or just being generous. I think the movie is a little too long,
# Processing prompt 81/100
# Prompt: I caught this on IFC last week and I thought it was typical of the
# Completion: I caught this on IFC last week and I thought it was typical of the genre. I was wrong. I think it's a great movie. I think it's a great movie. I think it's a great movie. I think it's
# Processing prompt 82/100
# Prompt: Acolytes presents an interesting mix of original concepts in "screaming teen" cliché horror with a
# Completion: Acolytes presents an interesting mix of original concepts in "screaming teen" cliché horror with a twist that is both hilarious and disturbing. The film is a bit slow, but it's a good film to watch if you're looking for
# Processing prompt 83/100
# Prompt: This was a decent movie for the first half. Too many cheap BOO! moments but
# Completion: This was a decent movie for the first half. Too many cheap BOO! moments but the rest of the movie was good. The acting was good, the plot was good, and the acting was good. The acting was good, the plot was
# Processing prompt 84/100
# Prompt: A rather lame teen slasher from Brisbane. While the plot hinges on a fairly decent
# Completion: A rather lame teen slasher from Brisbane. While the plot hinges on a fairly decent plot, the acting is poor and the plot is rather predictable. The only good thing about this movie is that it is a bit of a bore.
# Processing prompt 85/100
# Prompt: I was completely bored with this film, melodramatic for no apparent reason. Every thing just
# Completion: I was completely bored with this film, melodramatic for no apparent reason. Every thing just seemed to be a chore to watch. The acting was terrible, the script was terrible, and the direction was terrible. I was so bored that I
# Processing prompt 86/100
# Prompt: Art-house horror tries to use unconventional aesthetics to cover the fact that this is just
# Completion: Art-house horror tries to use unconventional aesthetics to cover the fact that this is just a movie about a man who is a serial killer. The film is a bit of a mess, but it's a good movie.
# Processing prompt 87/100
# Prompt: The film opens with a cult leader attempting to resurrect a dead member with his
# Completion: The film opens with a cult leader attempting to resurrect a dead member with his own body. The cult leader is a man who has been killed by a group of people who have been killed by a group of people who have been killed by a group of
# Processing prompt 88/100
# Prompt: I bought this on VHS as "Terror Hospital", and when I got home I checked
# Completion: I bought this on VHS as "Terror Hospital", and when I got home I checked it out. I was surprised to find that it was a very good horror movie. I was also surprised to find that it was a very good horror movie.
# Processing prompt 89/100
# Prompt: This is a hard film to rate. While it truly deserves its 3 (or perhaps
# Completion: This is a hard film to rate. While it truly deserves its 3 (or perhaps 4) stars, it is not a masterpiece. It is a film that is not worth watching.
# Processing prompt 90/100
# Prompt: I only came here to check Terror Hospital for an alternate title so I'd know
# Completion: I only came here to check Terror Hospital for an alternate title so I'd know what to expect. I was expecting a horror movie, but I was expecting a horror movie. I was expecting a horror movie. I was expecting a horror movie. I
# Processing prompt 91/100
# Prompt: The first 20 minutes were a little fun because I don't think I've seen a
# Completion: The first 20 minutes were a little fun because I don't think I've seen a movie that has a lot of action. The second 20 minutes were a little more interesting because I think I've seen a lot of action. The third 20 minutes were
# Processing prompt 92/100
# Prompt: This film, which I rented under the title "Black Voodoo" should be avoided. I was
# Completion: This film, which I rented under the title "Black Voodoo" should be avoided. I was not expecting much from this film, but I was expecting something different. I was expecting something different from the film, and I was expecting something different from
# Processing prompt 93/100
# Prompt: Maniratnam, who in India, is often compared with prominent world film makers and is regarded
# Completion: Maniratnam, who in India, is often compared with prominent world film makers and is regarded as a genius, is a man who has a great deal of talent. He is a man who has a great deal of talent. He is a
# Processing prompt 94/100
# Prompt: Jacqueline Hyde starts like any other normal day for telemarketing individual Jackie Hyde (co-producer Gabriella
# Completion: Jacqueline Hyde starts like any other normal day for telemarketing individual Jackie Hyde (co-producer Gabriella D'Amato) and her husband, who is a former high school football player. Jackie is a very good actress,
# Processing prompt 95/100
# Prompt: Sorry, but Jacqueline Hyde (get it??? - Jack L and Hyde - Jekyll & Hyde)
# Completion: Sorry, but Jacqueline Hyde (get it??? - Jack L and Hyde - Jekyll & Hyde) is a very good actress. She is a very good actress. She is a very good actress. She is a very good actress. She
# Processing prompt 96/100
# Prompt: This film seems well made, and more efforts should be made to promote films by
# Completion: This film seems well made, and more efforts should be made to promote films by the same people.
# Processing prompt 97/100
# Prompt: It hurt to watch this movie, it really did... I wanted to like it, even
# Completion: It hurt to watch this movie, it really did... I wanted to like it, even though I was a little disappointed. I was hoping for a good story, but it just didn't happen. I was hoping for a good story, but it
# Processing prompt 98/100
# Prompt: Rita Hayworth is just stunning at times and, for me, the only reason to watch
# Completion: Rita Hayworth is just stunning at times and, for me, the only reason to watch this movie is because of her performance. She is a very good actress and I think she is a very good actress. I think she is a very good
# Processing prompt 99/100
# Prompt: Like 'Singin' in the Rain', 'Cover Girl' has a trio of two guys and a
# Completion: Like 'Singin' in the Rain', 'Cover Girl' has a trio of two guys and a girl who are both in love with each other. The two girls are in love with each other, but they are not in love with each other
# Processing prompt 100/100
# Prompt: Rita Hayworth plays a Brooklyn nightclub dancer named Rusty who specializes in cheesecake chorus revues;
# Completion: Rita Hayworth plays a Brooklyn nightclub dancer named Rusty who specializes in cheesecake chorus revues; she's also a dancer who's been in the business for a while. She's a very good dancer, but she's not a good dancer.
# Average Reward: -9.562892810158107, Average KL Divergence: 5.217554635682182e-08
# Processing prompt 1/100
# Prompt: I love sci-fi and am willing to put up with a lot. Sci-fi movies/TV are
# Completion: I love sci-fi and am willing to put up with a lot. Sci-fi movies/TV are not for everyone, but I do enjoy them. I love the fact that the characters are real people, and that they are not just a
# Processing prompt 2/100
# Prompt: Worth the entertainment value of a rental, especially if you like action movies. This one
# Completion: Worth the entertainment value of a rental, especially if you like action movies. This one is a must see.
# Processing prompt 3/100
# Prompt: its a totally average film with a few semi-alright action sequences that make the plot
# Completion: its a totally average film with a few semi-alright action sequences that make the plot seem like it's going nowhere. The acting is average, the script is bad, and the acting is bad. The only thing that makes this film worth watching
# Processing prompt 4/100
# Prompt: STAR RATING: ***** Saturday Night **** Friday Night *** Friday Morning ** Sunday Night *
# Completion: STAR RATING: ***** Saturday Night **** Friday Night *** Friday Morning ** Sunday Night * Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning *** Monday Morning
# Processing prompt 5/100
# Prompt: First off let me say, If you haven't enjoyed a Van Damme movie since bloodsport,
# Completion: First off let me say, If you haven't enjoyed a Van Damme movie since bloodsport, then you'll love this one. It's a great movie, and I'm sure you'll enjoy it too.
# Processing prompt 6/100
# Prompt: I had high hopes for this one until they changed the name to 'The Shepherd
# Completion: I had high hopes for this one until they changed the name to 'The Shepherd'. I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good
# Processing prompt 7/100
# Prompt: Isaac Florentine has made some of the best western Martial Arts action movies ever produced.
# Completion: Isaac Florentine has made some of the best western Martial Arts action movies ever produced. He is a master of the martial arts and has made some of the best western action movies ever made. He is a master of the martial arts and has
# Processing prompt 8/100
# Prompt: It actually pains me to say it, but this movie was horrible on every level.
# Completion: It actually pains me to say it, but this movie was horrible on every level. The acting was terrible, the plot was terrible, the acting was terrible, the plot was terrible, the acting was terrible, the acting was terrible, the acting was
# Processing prompt 9/100
# Prompt: Technically I'am a Van Damme Fan, or I was. this movie is so bad that
# Completion: Technically I'am a Van Damme Fan, or I was. this movie is so bad that I'm going to give it a 10.
# Processing prompt 10/100
# Prompt: Honestly awful film, bad editing, awful lighting, dire dialog and scrappy screenplay.<br /><br />The lighting
# Completion: Honestly awful film, bad editing, awful lighting, dire dialog and scrappy screenplay.<br /><br />The lighting is terrible, the acting is terrible, the script is bad, the acting is bad, the script is bad, the script is
# Processing prompt 11/100
# Prompt: This flick is a waste of time.I expect from an action movie to have more
# Completion: This flick is a waste of time.I expect from an action movie to have more than one action scene.The acting is terrible.The plot is so bad that it's hard to believe that it was made in the first place.The acting is
# Processing prompt 12/100
# Prompt: Blind Date (Columbia Pictures, 1934), was a decent film, but I have a few issues
# Completion: Blind Date (Columbia Pictures, 1934), was a decent film, but I have a few issues with it. First, the story is very predictable. The characters are all very predictable. The plot is very predictable. The acting is very predictable
# Processing prompt 13/100
# Prompt: I first watched this movie back in the mid/late 80's, when I was a kid.
# Completion: I first watched this movie back in the mid/late 80's, when I was a kid. I remember it as a very funny movie, and I still remember it as a very funny movie. I think it's a very good movie, and
# Processing prompt 14/100
# Prompt: I saw the Mogul Video VHS of this. That's another one of those old 1980s
# Completion: I saw the Mogul Video VHS of this. That's another one of those old 1980s horror movies that you can't get ahold of. I'm not sure if it was the original or the remake, but I think it was a
# Processing prompt 15/100
# Prompt: A group of heirs to a mysterious old mansion find out that they have to
# Completion: A group of heirs to a mysterious old mansion find out that they have to find out who the real owner of the mansion is. The film is a bit slow, but it's a good film.
# Processing prompt 16/100
# Prompt: Now, I LOVE Italian horror films. The cheesier they are, the better. However, this is
# Completion: Now, I LOVE Italian horror films. The cheesier they are, the better. However, this is a film that I would recommend to anyone who likes Italian horror films.
# Processing prompt 17/100
# Prompt: This cheap, grainy-filmed Italian flick is about a couple of inheritors of a manor in
# Completion: This cheap, grainy-filmed Italian flick is about a couple of inheritors of a manor in the Italian countryside. The film is about a couple of people who are trying to get their inheritance back. The film is about a couple of
# Processing prompt 18/100
# Prompt: I just finished watching this movie and am disappointed to say that I didn't enjoy
# Completion: I just finished watching this movie and am disappointed to say that I didn't enjoy it. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but I was disappointed. I was expecting a good movie, but
# Processing prompt 19/100
# Prompt: Ben, (Rupert Grint), is a deeply unhappy adolescent, the son of his unhappily married parents.
# Completion: Ben, (Rupert Grint), is a deeply unhappy adolescent, the son of his unhappily married parents. He is a very good actor, but he is not a good actor. He is a very good actor, but he is not
# Processing prompt 20/100
# Prompt: Every movie I have PPV'd because Leonard Maltin praised it to the skies has blown
# Completion: Every movie I have PPV'd because Leonard Maltin praised it to the skies has blown me away. I have seen it twice and I have seen it twice more. I have seen it twice and I have seen it twice more. I have seen
# Processing prompt 21/100
# Prompt: Low budget horror movie. If you don't raise your expectations too high, you'll probably enjoy
# Completion: Low budget horror movie. If you don't raise your expectations too high, you'll probably enjoy this one.
# Processing prompt 22/100
# Prompt: Dr Stephens (Micheal Harvey) runs a mental asylum. He has a different approach to the
# Completion: Dr Stephens (Micheal Harvey) runs a mental asylum. He has a different approach to the asylum, and he is a bit of a jerk. He is a bit of a jerk, but he is a jerk nonetheless. He is a jerk
# Processing prompt 23/100
# Prompt: The Forgotten (AKA: Don't Look In The Basement) is a very cheaply made and very
# Completion: The Forgotten (AKA: Don't Look In The Basement) is a very cheaply made and very poorly acted film. The acting is poor and the script is very poor. The only reason I gave it a 7 is because of the fact that
# Processing prompt 24/100
# Prompt: This movie had a very unique effect on me: it stalled my realization that this
# Completion: This movie had a very unique effect on me: it stalled my realization that this was a movie that I was going to watch for the rest of my life. I was so excited to see this movie, I was so excited to see the movie that
# Processing prompt 25/100
# Prompt: too bad this movie isn't. While "Nemesis Game" is mildly entertaining, I found it hard
# Completion: too bad this movie isn't. While "Nemesis Game" is mildly entertaining, I found it hard to believe that it would be so bad. The acting is terrible, the plot is so bad, and the acting is so bad that it
# Processing prompt 26/100
# Prompt: I of course saw the previews for this at the beginning of some other Lion's
# Completion: I of course saw the previews for this at the beginning of some other Lion's Gate movies, and I was very impressed. I was also very impressed with the way the movie was shot. The camera work was very good, and the acting was very
# Processing prompt 27/100
# Prompt: I gave this a 3 out of a possible 10 stars.<br /><br />Unless you like
# Completion: I gave this a 3 out of a possible 10 stars.<br /><br />Unless you like to see a good movie with a good story, this is a must see.
# Processing prompt 28/100
# Prompt: I was looking forward to this movie. Trustworthy actors, interesting plot. Great atmosphere then ?????
# Completion: I was looking forward to this movie. Trustworthy actors, interesting plot. Great atmosphere then?????
# Processing prompt 29/100
# Prompt: Four things intrigued me as to this film - firstly, it stars Carly Pope (of
# Completion: Four things intrigued me as to this film - firstly, it stars Carly Pope (of the TV series 'The Simpsons') as the main character, and secondly, it is a very funny film. The humour is very good, and the characters are
# Processing prompt 30/100
# Prompt: <br /><br />Never ever take a film just for its good looking title.<br /><br />Although
# Completion: <br /><br />Never ever take a film just for its good looking title.<br /><br />Although the film is a bit slow, it is still a good film. The acting is good, the story is good, and the
# Processing prompt 31/100
# Prompt: Lowe returns to the nest after, yet another, failed relationship, to find he's been assigned
# Completion: Lowe returns to the nest after, yet another, failed relationship, to find he's been assigned to a different job. He's a man who's been in a relationship for a long time, and he's not happy with the way things are
# Processing prompt 32/100
# Prompt: Seriously, I can't imagine how anyone could find a single flattering thing to say about
# Completion: Seriously, I can't imagine how anyone could find a single flattering thing to say about this movie. I'm not even going to go into the plot, but I'll just say that it's a very bad movie. I'm not even going to
# Processing prompt 33/100
# Prompt: I'm the type of guy who loves hood movies from New Jack City to Baby
# Completion: I'm the type of guy who loves hood movies from New Jack City to Baby Driver. I'm also a big fan of the "The Big Chill" series, which I've seen a lot. I'm also a big fan of the "The
# Processing prompt 34/100
# Prompt: The most positive points in this film were the credits (text style) and some moments
# Completion: The most positive points in this film were the credits (text style) and some moments of humor. The film was a bit slow, but it was a good film.
# Processing prompt 35/100
# Prompt: I quite enjoyed The Wrecking Crew (1999), which was the last of the three films
# Completion: I quite enjoyed The Wrecking Crew (1999), which was the last of the three films I saw. I was very impressed with the direction and the acting. The film was very well done and the story was very well told. The acting was
# Processing prompt 36/100
# Prompt: this film has no plot, no good acting, to be honest it has nothing, the
# Completion: this film has no plot, no good acting, to be honest it has nothing, the only thing that makes it worth watching is the music. I think it's a shame that the director didn't make a sequel to this one.
# Processing prompt 37/100
# Prompt: Beware, My Lovely (1952) Dir: Harry Horner <br /><br />Production: The Filmmakers/RKO Radio Pictures<br /><br
# Completion: Beware, My Lovely (1952) Dir: Harry Horner <br /><br />Production: The Filmmakers/RKO Radio Pictures<br /><br />Director: Harry Horner <br /><br />Director:
# Processing prompt 38/100
# Prompt: The only reason this movie is not given a 1 (awful) vote is that the
# Completion: The only reason this movie is not given a 1 (awful) vote is that the movie is so bad it's hard to believe it was made in the first place. The acting is terrible, the plot is so bad it's hard to believe
# Processing prompt 39/100
# Prompt: Artificial melodrama with a screenplay adapted by Mel Dinelli from his play "The Man" concerns
# Completion: Artificial melodrama with a screenplay adapted by Mel Dinelli from his play "The Man" concerns a young man who is sent to a boarding school for his studies. He is sent to a boarding school for his studies, but he is not
# Processing prompt 40/100
# Prompt: Wow, what an overrated movie this turned out to be! It was supposed to be
# Completion: Wow, what an overrated movie this turned out to be! It was supposed to be a comedy, but it was just a bunch of people laughing at each other. I mean, it was supposed to be a comedy, but it was just a
# Processing prompt 41/100
# Prompt: I can't believe the high marks people have given this film on this site. The
# Completion: I can't believe the high marks people have given this film on this site. The acting is terrible, the script is terrible, the direction is terrible, the direction is terrible, the direction is terrible, the direction is terrible, the direction is terrible
# Processing prompt 42/100
# Prompt: Widow hires a psychopath as a handyman. Sloppy film noir thriller which doesn't make much
# Completion: Widow hires a psychopath as a handyman. Sloppy film noir thriller which doesn't make much sense. The plot is a bit predictable, but the acting is good. The story is a bit predictable, but the acting is good.
# Processing prompt 43/100
# Prompt: I have no idea how anyone can give this movie high marks. I didn't rent
# Completion: I have no idea how anyone can give this movie high marks. I didn't rent it because I was bored and I didn't want to waste my time. I rented it because I was bored and I didn't want to waste my time.
# Processing prompt 44/100
# Prompt: Seeing the title of this movie "Stupid Teenagers Must Die" made me believe this was
# Completion: Seeing the title of this movie "Stupid Teenagers Must Die" made me believe this was a movie that would be a hit. I was wrong. I was wrong. I was wrong. I was wrong. I was wrong. I was wrong
# Processing prompt 45/100
# Prompt: Now I understand that this took two months to shoot. Really? I'm pretty certain my
# ...
# Processing prompt 55/100
# Prompt: An Italian/American co-production co-starring Linda Blair and David 'The Hoff' Hasselhoff: how could any fan
# Completion: An Italian/American co-production co-starring Linda Blair and David 'The Hoff' Hasselhoff: how could any fan of the genre ever get involved in this film?<br /><br />The film is a very good example
# Processing prompt 56/100
# Prompt: Oh my... bad clothing, worse synth music and the worst: David Hasselhoff. The 80's are
# Completion: Oh my... bad clothing, worse synth music and the worst: David Hasselhoff. The 80's are a time when the music was more than just a bunch of people playing a song. The 80's were a time when the music was more
# Processing prompt 57/100
# Prompt: There are many different versions of this one floating around, so make sure you can
# Completion: There are many different versions of this one floating around, so make sure you can find the one you like.
# Processing prompt 58/100
# Prompt: Witchcraft/Witchery/La Casa 4/ and whatever else you wish to call it. How about..Crud.<br /><br />A
# Completion: Witchcraft/Witchery/La Casa 4/ and whatever else you wish to call it. How about..Crud.<br /><br />A lot of people have commented on the fact that the movie is a bit too long
# Processing prompt 59/100
# Prompt: "Witchery" might just be the most incoherent and lamentably scripted horror movie of the 80's
# Completion: "Witchery" might just be the most incoherent and lamentably scripted horror movie of the 80's. The plot is so bad it's almost laughable. The acting is so bad it's almost laughable. The acting is so bad it's
# Processing prompt 60/100
# Prompt: Witchy Hildegard Knef traps a group of people in an isolated hotel and picks them
# Completion: Witchy Hildegard Knef traps a group of people in an isolated hotel and picks them up. The film is a bit slow, but it's still a good film.
# Processing prompt 61/100
# Prompt: A really very bad movie, with a very few good moments or qualities.<br /><br />It
# Completion: A really very bad movie, with a very few good moments or qualities.<br /><br />It's a shame that the movie was not released in the US.
# Processing prompt 62/100
# Prompt: This film features two of my favorite guilty pleasures. Sure, the effects are laughable, the
# Completion: This film features two of my favorite guilty pleasures. Sure, the effects are laughable, the acting is terrible, and the plot is a little too predictable. But the film is worth watching for the sheer sheer brilliance of the characters.
# Processing prompt 63/100
# Prompt: I watched this movie purely for the setting. It was filmed in an old hotel
# Completion: I watched this movie purely for the setting. It was filmed in an old hotel in the middle of nowhere, and the actors were all in their early twenties. The movie was shot in a small town in the middle of nowhere, and the actors were
# Processing prompt 64/100
# Prompt: This only gets bashed because it stars David Hasselhoff. Well, then let me bash it
# Completion: This only gets bashed because it stars David Hasselhoff. Well, then let me bash it. I'm not sure if it's because of the fact that Hasselhoff is a big fan of the show, or because he's a big
# Processing prompt 65/100
# Prompt: We brought this film as a joke for a friend, and could of been our
# Completion: We brought this film as a joke for a friend, and could of been our best friend. We were both very happy with the film, and we were both very happy with the ending. I think it was a very good film, and I think
# Processing prompt 66/100
# Prompt: Humm, an Italian movie starred by David hasselhoff and Linda Blair, I wasn´t expecting very
# Completion: Humm, an Italian movie starred by David hasselhoff and Linda Blair, I wasn´t expecting very much from this movie. The plot is very simple, the characters are very well developed and the story is very well told. The acting is
# Processing prompt 67/100
# Prompt: I and a friend rented this movie. We both found the movie soundtrack and production
# Completion: I and a friend rented this movie. We both found the movie soundtrack and production values to be very good. The acting was very good and the story was very well told. The movie was very well written and acted. The movie was very well acted
# Processing prompt 68/100
# Prompt: I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up
# Completion: I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up being boring. I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up being boring.
# Processing prompt 69/100
# Prompt: Not like I went in expecting a lot out of it, but I was at
# Completion: Not like I went in expecting a lot out of it, but I was at least expecting a good movie. I was expecting a good movie, but I was expecting a bad movie. I was expecting a bad movie, but I was expecting a good
# Processing prompt 70/100
# Prompt: That snarl...<br /><br />That scowl...<br /><br />The acts of random violence...<br /><br />The gutteral voice...<br
# Completion: That snarl...<br /><br />That scowl...<br /><br />The acts of random violence...<br /><br />The gutteral voice...<br /><br />The sound of the car...
# Processing prompt 71/100
# Prompt: generally speaking I don't make negative comments on here. But since this is a festival
# Completion: generally speaking I don't make negative comments on here. But since this is a festival, I thought it would be a good idea to give it a try. I was pleasantly surprised by the quality of the film. The acting was good, the
# Processing prompt 72/100
# Prompt: This show should be titled, "When Bad Writing Happens To Good Actors" considering most of
# Completion: This show should be titled, "When Bad Writing Happens To Good Actors" considering most of the actors are in their late 30s or early 40s. The show is a great example of how to make a good actor look good. The
# Processing prompt 73/100
# Prompt: I thought maybe... maybe this could be good. An early appearance by the Re-Animator (Jeffery
# Completion: I thought maybe... maybe this could be good. An early appearance by the Re-Animator (Jeffery) and a cameo by the "Citizen Kane" (John Cusack) was a good idea. The movie was a bit slow
# Processing prompt 74/100
# Prompt: 1983's "Frightmare" is an odd little film. The director seems to be trying to combine
# Completion: 1983's "Frightmare" is an odd little film. The director seems to be trying to combine the best of the best of the best, but it's not quite as good as the first film. The film is a bit slow, but
# Processing prompt 75/100
# Prompt: I don't get it! The teenage leads in "Horror Star" supposedly all are devoted horror
# Completion: I don't get it! The teenage leads in "Horror Star" supposedly all are devoted horror fans, but they're not. The film is a complete waste of time and money. The acting is atrocious, the direction is atrocious,
# Processing prompt 76/100
# Prompt: Conrad Radzoff(Ferdy Mayne), a hammy cult icon, dies from a heart ailment(not before disposing of
# Completion: Conrad Radzoff(Ferdy Mayne), a hammy cult icon, dies from a heart ailment(not before disposing of his body)and his wife, who is a devoted mother, is left to fend for herself. The
# Processing prompt 77/100
# Prompt: One of the last surviving horror screen greats - Conrad Radzoff - dies and has
# Completion: One of the last surviving horror screen greats - Conrad Radzoff - dies and has to be buried in a cemetery. He is buried in a cemetery, and the cemetery is haunted by a ghost. The ghost is a young woman who is a
# Processing prompt 78/100
# Prompt: My parents used to rent a lot of horror movies when I was a child.
# Completion: My parents used to rent a lot of horror movies when I was a child. I remember seeing this movie when I was a kid and I was very excited to see it. I was very excited to see it when I was a kid and I was
# Processing prompt 79/100
# Prompt: Frightmare begins with a horror movie icon killing a director and then his servant before
# Completion: Frightmare begins with a horror movie icon killing a director and then his servant before he can kill himself. The film is a bit of a mess, but it's a good one. The acting is good, the plot is good, and the
# Processing prompt 80/100
# Prompt: It's Saturday, it's raining, and I think every movie should have at least one comment...
# Completion: It's Saturday, it's raining, and I think every movie should have at least one comment...<br /><br />I'm not sure if I'm being generous or just being generous. I think the movie is a little too long,
# Processing prompt 81/100
# Prompt: I caught this on IFC last week and I thought it was typical of the
# Completion: I caught this on IFC last week and I thought it was typical of the genre. I was wrong. I think it's a great movie. I think it's a great movie. I think it's a great movie. I think it's
# Processing prompt 82/100
# Prompt: Acolytes presents an interesting mix of original concepts in "screaming teen" cliché horror with a
# Completion: Acolytes presents an interesting mix of original concepts in "screaming teen" cliché horror with a twist that is both hilarious and disturbing. The film is a bit slow, but it's a good film to watch if you're looking for
# Processing prompt 83/100
# Prompt: This was a decent movie for the first half. Too many cheap BOO! moments but
# Completion: This was a decent movie for the first half. Too many cheap BOO! moments but the rest of the movie was good. The acting was good, the plot was good, and the acting was good. The acting was good, the plot was
# Processing prompt 84/100
# Prompt: A rather lame teen slasher from Brisbane. While the plot hinges on a fairly decent
# Completion: A rather lame teen slasher from Brisbane. While the plot hinges on a fairly decent plot, the acting is poor and the plot is rather predictable. The only good thing about this movie is that it is a bit of a bore.
# Processing prompt 85/100
# Prompt: I was completely bored with this film, melodramatic for no apparent reason. Every thing just
# Completion: I was completely bored with this film, melodramatic for no apparent reason. Every thing just seemed to be a chore to watch. The acting was terrible, the script was terrible, and the direction was terrible. I was so bored that I
# Processing prompt 86/100
# Prompt: Art-house horror tries to use unconventional aesthetics to cover the fact that this is just
# Completion: Art-house horror tries to use unconventional aesthetics to cover the fact that this is just a movie about a man who is a serial killer. The film is a bit of a mess, but it's a good movie.
# Processing prompt 87/100
# Prompt: The film opens with a cult leader attempting to resurrect a dead member with his
# Completion: The film opens with a cult leader attempting to resurrect a dead member with his own body. The cult leader is a man who has been killed by a group of people who have been killed by a group of people who have been killed by a group of
# Processing prompt 88/100
# Prompt: I bought this on VHS as "Terror Hospital", and when I got home I checked
# Completion: I bought this on VHS as "Terror Hospital", and when I got home I checked it out. I was surprised to find that it was a very good horror movie. I was also surprised to find that it was a very good horror movie.
# Processing prompt 89/100
# Prompt: This is a hard film to rate. While it truly deserves its 3 (or perhaps
# Completion: This is a hard film to rate. While it truly deserves its 3 (or perhaps 4) stars, it is not a masterpiece. It is a film that is not worth watching.
# Processing prompt 90/100
# Prompt: I only came here to check Terror Hospital for an alternate title so I'd know
# Completion: I only came here to check Terror Hospital for an alternate title so I'd know what to expect. I was expecting a horror movie, but I was expecting a horror movie. I was expecting a horror movie. I was expecting a horror movie. I
# Processing prompt 91/100
# Prompt: The first 20 minutes were a little fun because I don't think I've seen a
# Completion: The first 20 minutes were a little fun because I don't think I've seen a movie that has a lot of action. The second 20 minutes were a little more interesting because I think I've seen a lot of action. The third 20 minutes were
# Processing prompt 92/100
# Prompt: This film, which I rented under the title "Black Voodoo" should be avoided. I was
# Completion: This film, which I rented under the title "Black Voodoo" should be avoided. I was not expecting much from this film, but I was expecting something different. I was expecting something different from the film, and I was expecting something different from
# Processing prompt 93/100
# Prompt: Maniratnam, who in India, is often compared with prominent world film makers and is regarded
# Completion: Maniratnam, who in India, is often compared with prominent world film makers and is regarded as a genius, is a man who has a great deal of talent. He is a man who has a great deal of talent. He is a
# Processing prompt 94/100
# Prompt: Jacqueline Hyde starts like any other normal day for telemarketing individual Jackie Hyde (co-producer Gabriella
# Completion: Jacqueline Hyde starts like any other normal day for telemarketing individual Jackie Hyde (co-producer Gabriella D'Amato) and her husband, who is a former high school football player. Jackie is a very good actress,
# Processing prompt 95/100
# Prompt: Sorry, but Jacqueline Hyde (get it??? - Jack L and Hyde - Jekyll & Hyde)
# Completion: Sorry, but Jacqueline Hyde (get it??? - Jack L and Hyde - Jekyll & Hyde) is a very good actress. She is a very good actress. She is a very good actress. She is a very good actress. She
# Processing prompt 96/100
# Prompt: This film seems well made, and more efforts should be made to promote films by
# Completion: This film seems well made, and more efforts should be made to promote films by the same people.
# Processing prompt 97/100
# Prompt: It hurt to watch this movie, it really did... I wanted to like it, even
# Completion: It hurt to watch this movie, it really did... I wanted to like it, even though I was a little disappointed. I was hoping for a good story, but it just didn't happen. I was hoping for a good story, but it
# Processing prompt 98/100
# Prompt: Rita Hayworth is just stunning at times and, for me, the only reason to watch
# Completion: Rita Hayworth is just stunning at times and, for me, the only reason to watch this movie is because of her performance. She is a very good actress and I think she is a very good actress. I think she is a very good
# Processing prompt 99/100
# Prompt: Like 'Singin' in the Rain', 'Cover Girl' has a trio of two guys and a
# Completion: Like 'Singin' in the Rain', 'Cover Girl' has a trio of two guys and a girl who are both in love with each other. The two girls are in love with each other, but they are not in love with each other
# Processing prompt 100/100
# Prompt: Rita Hayworth plays a Brooklyn nightclub dancer named Rusty who specializes in cheesecake chorus revues;
# Completion: Rita Hayworth plays a Brooklyn nightclub dancer named Rusty who specializes in cheesecake chorus revues; she's also a dancer who's been in the business for a while. She's a very good dancer, but she's not a good dancer.
# Average Reward: -9.562892810158107, Average KL Divergence: -5.6840184964565436e-08
# Model: ./pareto_models/model_weights_0.pth, Avg Reward: -9.562892810158107, Avg KL Divergence: 5.217554635682182e-08
# Model: ./pareto_models/model_weights_1.pth, Avg Reward: -9.562892810158107, Avg KL Divergence: -2.0906355819474615e-07
# Model: ./pareto_models/model_weights_2.pth, Avg Reward: -9.562892810158107, Avg KL Divergence: -1.3481394829469814e-07
# Model: ./pareto_models/model_weights_3.pth, Avg Reward: -9.562892810158107, Avg KL Divergence: -1.5812865992460422e-09
# Model: ./pareto_models/model_weights_4.pth, Avg Reward: -9.562892810158107, Avg KL Divergence: -2.9305190822795973e-07
# Model: SFT Model, Avg Reward: -9.562892810158107, Avg KL Divergence: -6.657664471894666e-08
# Model: Model, Avg Reward: -9.562892810158107, Avg KL Divergence: -5.6840184964565436e-08

# %%
import matplotlib.pyplot as plt

# Гипотетический пример значений для I, M и T
I_values = [2, 3, 4]
M_values = [5, 10, 15]
T_values = [50, 100, 150]

# Средние награды и KL дивергенции, полученные из экспериментов
avg_rewards = [result[1] for result in results[:-1]]
avg_kl_divs = [result[2] for result in results[:-1]]

plt.figure(figsize=(10, 5))
plt.plot(I_values, avg_rewards, label="Avg Reward", marker='o')
plt.plot(I_values, avg_kl_divs, label="Avg KL Divergence", marker='x')
plt.xlabel("I Values")
plt.ylabel("Metrics")
plt.legend()
plt.title("Impact of I on Average Reward and KL Divergence")
plt.show()
